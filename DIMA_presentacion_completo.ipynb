# %% [markdown]
# # **Diccionario Mágico para Atrevidos (DIMA)** 🌟
# **Autor:** Rocío Dopazo
# **Curso:** Generación de Prompts | **Comisión:** 67115
# **Fecha:** 17/12/2024
#
# ---
#
# ## **Título del Proyecto**
# **Diccionario Mágico para Atrevidos (DIMA)**
#
# ---
#
# ## **Resumen** 📄
# El **Diccionario Mágico para Atrevidos (DIMA)** es una herramienta interactiva basada en **IA generativa** que permite analizar palabras y conceptos complejos, proporcionando explicaciones claras y visuales. Utiliza **GPT-4** y **DALL·E** para generar análisis textuales profundos y representaciones visuales creativas, respectivamente. Gracias a su integración de **Fast Prompting** y caché local, DIMA optimiza recursos y mejora la experiencia del usuario.
#
# ---
#
# ## **Introducción** 🎯
# ### **Problema a abordar:**
# La falta de comprensión clara de conceptos complejos o palabras abstractas, especialmente aquellas con connotaciones negativas, afecta la comunicación efectiva y la percepción emocional.
#
# ### **Solución planteada:**
# El Diccionario Mágico para Atrevidos (DIMA) analiza palabras y conceptos en tres dimensiones clave: etimología, significado derivado y energía vibracional. Además, genera imágenes representativas que ayudan al usuario a transformar términos negativos en positivos.
#
# ---
#
# ## **Objetivos del Proyecto** 🎯
# 1. Proporcionar explicaciones claras y comprensibles de palabras y conceptos complejos.
# 2. Identificar la energía vibracional de las palabras y sugerir alternativas positivas.
# 3. Crear representaciones visuales alineadas con los análisis textuales.
# 4. Diseñar un menú interactivo amigable que facilite el uso de la herramienta.
#
# ---
#
# ## **Metodología** ⚙️
# 1. **Análisis textual:** Uso de **GPT-4** para descomponer palabras y conceptos en:
#    - **Etimología**: Origen histórico y cultural.
#    - **Explicación derivada**: Significado actual y contexto.
#    - **Energía vibracional**: Alta, neutral o baja, con justificación.
# 2. **Generación visual:** Implementación de **DALL·E** para crear imágenes basadas en el análisis textual y vibracional.
# 3. **Caché local:** Almacenar resultados previos para evitar consultas redundantes y optimizar recursos.
# 4. **Menú interactivo:** Crear una experiencia fluida, con indicadores de progreso y resultados dinámicos.
#
# ### **Justificación de la Metodología:**
# - **Fast Prompting** permite optimizar consultas para obtener resultados precisos y rápidos.
# - La integración de análisis textual y visual asegura una experiencia completa y enriquecedora para el usuario.
# - La implementación de caché mejora el rendimiento y reduce costos.
#
# ---
#
# ## **Herramientas y Tecnologías** 🛠️
# | Herramienta / Librería      | Propósito                             | Justificación                        |
# |-----------------------------|---------------------------------------|--------------------------------------|
# | **OpenAI GPT-4**            | Generación de análisis textuales      | Profundidad y precisión en los prompts |
# | **DALL·E**                  | Generación de imágenes visuales       | Representaciones creativas y coherentes |
# | **NLTK**                    | Procesamiento básico del lenguaje     | Soporte etimológico y de vocabulario |
# | **IPython.display**         | Visualización interactiva             | Resultados con formato atractivo     |
# | **JSON**                    | Almacenamiento de resultados en caché | Optimización de recursos             |
#
# ---
#
# ## **Implementación del Proyecto** 🚀

# %%
# Código principal del proyecto: Incluye análisis textual, generación visual, y caché local

import openai
from IPython.display import display, HTML
import json, os, time

openai.api_key = "ACÁ VA TU API KEY"  # Reemplaza con tu clave válida

RESULTADOS_JSON = "resultados_diccionario.json"

if not os.path.exists(RESULTADOS_JSON):
    with open(RESULTADOS_JSON, "w") as f:
        json.dump({}, f)

def cargar_resultados():
    with open(RESULTADOS_JSON, "r") as f:
        return json.load(f)

def guardar_resultado(entrada, tipo, resultado, imagen_url):
    resultados = cargar_resultados()
    resultados[entrada] = {"tipo": tipo, "resultado": resultado, "imagen": imagen_url}
    with open(RESULTADOS_JSON, "w") as f:
        json.dump(resultados, f, indent=4)

def buscar_en_cache(entrada):
    resultados = cargar_resultados()
    return resultados.get(entrada, None)

def generar_prompt_visual(entrada, resultado_analisis, tipo):
    energia = "baja" if "baja" in resultado_analisis.lower() else "alta"
    prompt_base = f"Genera una imagen representando el {tipo} '{entrada}' basado en este análisis: {resultado_analisis}. "
    if energia == "baja":
        return prompt_base + "Usa tonos oscuros, apagados y tristes para reflejar una energía baja."
    else:
        return prompt_base + "Usa colores vivos, brillantes y positivos para reflejar una energía alta."

def generar_imagen(prompt):
    try:
        print("🎨 Generando imagen...")
        response = openai.Image.create(prompt=prompt[:1000], n=1, size="512x512")
        return response['data'][0]['url']
    except Exception as e:
        print(f"⚠️ Error al generar la imagen: {e}")
        return None

def analizar_entrada(entrada, tipo):
    cache = buscar_en_cache(entrada)
    if cache:
        print(f"✅ Resultado recuperado de caché para '{entrada}'.")
        return cache["resultado"], cache["imagen"]
    
    prompt = f"""Analiza el {tipo} '{entrada}' en las siguientes dimensiones:
    1. Etimología o contexto histórico-cultural.
    2. Explicación derivada y significado actual.
    3. Energía vibracional (alta, neutral o baja), con una justificación detallada.
    """
    if len(prompt) > 1000:
        prompt = prompt[:997] + "..."
    
    print(f"⏳ Analizando el {tipo} '{entrada}', por favor espera...")
    time.sleep(2)
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[{"role": "user", "content": prompt}]
        )
        resultado = response['choices'][0]['message']['content']
        prompt_visual = generar_prompt_visual(entrada, resultado, tipo)
        imagen_url = generar_imagen(prompt_visual)
        guardar_resultado(entrada, tipo, resultado, imagen_url)
        return resultado, imagen_url
    except Exception as e:
        print(f"⚠️ Error al analizar el {tipo}: {e}")
        return None, None

def mostrar_resultado(entrada, tipo, resultado, imagen_url):
    display(HTML(f"""
    <h2 style='color: #5C6BC0;'>🔍 Análisis del {tipo}: <em>{entrada}</em></h2>
    <p style='font-size: 16px; background-color: #F3F4F6; padding: 10px; border-radius: 5px;'>{resultado}</p>
    <h3 style='color: #42A5F5;'>🖼️ Imagen Generada:</h3>
    <img src='{imagen_url}' style='max-width: 50%; border: 2px solid #90CAF9; border-radius: 5px;'>
    """))

def menu_interactivo():
    while True:
        print("\n🌟 Menú del Diccionario Mágico 🌟")
        print("1. Analizar una palabra")
        print("2. Analizar un concepto")
        print("3. Salir")
        opcion = input("Selecciona una opción (1, 2 o 3): ").strip()
        if opcion == "1":
            palabra = input("🔍 Escribe la palabra a analizar: ").strip()
            resultado, imagen_url = analizar_entrada(palabra, "palabra")
            if resultado and imagen_url:
                mostrar_resultado(palabra, "palabra", resultado, imagen_url)
            else:
                print("⚠️ No se pudo completar el análisis para la palabra.")
        elif opcion == "2":
            concepto = input("🔍 Escribe el concepto a analizar: ").strip()
            resultado, imagen_url = analizar_entrada(concepto, "concepto")
            if resultado and imagen_url:
                mostrar_resultado(concepto, "concepto", resultado, imagen_url)
            else:
                print("⚠️ No se pudo completar el análisis para el concepto.")
        elif opcion == "3":
            print("Gracias por usar el Diccionario Mágico 🌟")
            break
        else:
            print("⚠️ Opción inválida. Por favor, elige 1, 2 o 3.")

menu_interactivo()
# Out:
# 🌟 Menú del Diccionario Mágico 🌟
# 1. Analizar una palabra
# 2. Analizar un concepto
# 3. Salir
# Selecciona una opción (1, 2 o 3):  1
# 🔍 Escribe la palabra a analizar:  miedo
# ✅ Resultado recuperado de caché para 'miedo'.
#     <h2 style='color: #5C6BC0;'>🔍 Análisis del palabra: <em>miedo</em></h2>
#     <p style='font-size: 16px; background-color: #F3F4F6; padding: 10px; border-radius: 5px;'>1. Etimología: La palabra "miedo" proviene del latín "metus", que se traduce como miedo, terror o pánico. Históricamente, el miedo ha sido una emoción esencial para la supervivencia humana, haciendo que los individuos se alejen de peligros potenciales. En la antigüedad, el miedo a menudo estaba asociado con la superstición y lo desconocido, lo cual se refleja en su uso en la literatura y el arte antiguo.
#
# ...

# %% [markdown]
# ---
#
# ## **Resultados** 📊
# - El análisis textual proporciona explicaciones claras y completas, desglosadas en etimología, significado derivado y energía vibracional.
# - Las imágenes generadas reflejan coherentemente la vibración energética y el análisis textual.
#
# ---
#
# ## **Conclusiones** 🎯
# El proyecto Diccionario Mágico para Atrevidos (DIMA) ha logrado cumplir con los objetivos planteados, proporcionando una herramienta integral para analizar y transformar palabras y conceptos complejos. Su enfoque innovador, basado en la integración de análisis textual y visual mediante IA generativa, permite desglosar términos abstractos en dimensiones comprensibles y ofrecer representaciones visuales alineadas con su energía vibracional.
#
# ---
#
# ### **Desafíos Superados**
# Durante el desarrollo del proyecto, se enfrentaron varios desafíos significativos:
#
# Límites en la longitud de los prompts: Uno de los retos principales fue ajustar los prompts a las restricciones de caracteres impuestas por las APIs de OpenAI. Este obstáculo se resolvió mediante la optimización y segmentación de los prompts, asegurando que cada análisis se mantuviera claro y funcional.
#
# Coherencia entre análisis textual y visual: Crear imágenes que no solo representaran el análisis textual, sino que también fueran coherentes con la energía vibracional descrita, representó un desafío conceptual. Se lograron resultados satisfactorios ajustando los prompts visuales para reflejar fielmente las características de cada palabra o concepto.
#
# Experiencia del usuario: Diseñar un menú interactivo que fuera intuitivo, informativo y eficiente exigió iteraciones cuidadosas. La implementación de indicadores de progreso y el uso de caché local mejoraron significativamente la experiencia general.
#
# ---
#
# ### **Dificultades Encontradas**
# Dependencia de APIs externas: La generación de texto e imágenes está limitada por la disponibilidad y restricciones de las herramientas utilizadas (GPT-4 y DALL·E). En algunos casos, estas dependencias afectaron el rendimiento y la fluidez del proceso.
# Representación de conceptos abstractos: Traducir conceptos altamente subjetivos en imágenes visuales requería una interpretación precisa y muchas veces subjetiva, lo cual podía resultar en resultados inesperados o difíciles de alinear con el análisis textual.
# Potenciales Optimizaciones y Futuro del Proyecto
# El desarrollo de DIMA abre una amplia gama de posibilidades para optimización y expansión futura:
#
# Mejoras en la generación visual: Implementar herramientas adicionales para la generación de imágenes, como modelos de código abierto (e.g., Stable Diffusion), permitiría un control más detallado de los resultados visuales y una mayor personalización.
#
# Extensión a idiomas múltiples: Aunque actualmente DIMA está diseñado principalmente para español, la incorporación de análisis multilingüe permitiría expandir su alcance a usuarios globales, mejorando su accesibilidad y relevancia.
#
# Desarrollo de métricas de calidad: Incluir un sistema de retroalimentación para que los usuarios califiquen los resultados visuales y textuales podría permitir ajustes dinámicos y personalizaciones basadas en preferencias individuales.
#
# Integración con interfaces avanzadas: Incorporar una interfaz gráfica (GUI) o una aplicación web podría facilitar la interacción del usuario con el sistema, mejorando aún más la experiencia.
#
# Ampliación del enfoque analítico: Además del análisis de palabras y conceptos, DIMA podría incluir análisis de frases completas, textos largos y su contexto emocional o energético.
#
# Aprendizaje incremental: Implementar un modelo que aprenda de los resultados más utilizados o valorados podría optimizar los análisis futuros, mejorando la relevancia de las respuestas generadas.
#
# El desarrollo de DIMA ha permitido explorar los límites de las capacidades actuales de las herramientas de IA generativa y su potencial para resolver problemas concretos. Este proyecto no solo cumple con los objetivos del curso, sino que también ofrece una base sólida para futuras exploraciones en el ámbito de la interacción entre lenguaje, emoción y tecnología.
#
# ---
#
# ## **Referencias** 📚
# 1. OpenAI GPT-4 Documentation.
# 2. OpenAI DALL·E API.
# 3. NLTK Library Documentation.
